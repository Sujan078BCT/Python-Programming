# %% [markdown]
# <a href="https://colab.research.google.com/github/Sujan078BCT/Python-Programming/blob/main/Interview/Interview_Questions_Ans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python interview questions & answers

# %% [markdown]
# | Question No. | Question |
# | :--: | :-- |
# | 1 | What is Python? What are the benefits of using Python? |
# | 2 | What is a dynamically typed language? |
# | 3 | What is an Interpreted language? |
# | 4 | What is PEP 8 and why is it important? |
# | 5 | What are the common built-in data types in Python? |
# | 6 | Explain the ternary operator in Python. |
# | 7 | What Does the ‘is’ Operator Do? |
# | 8 | Disadvantages of Python. |
# | 9 | How strings are stored in Python? |
# | 10 | What is Zen of Python? |
# | 11 | Identity operator (is) vs ==? |
# | 12 | What does _ variables represent in Python? |
# | 13 | Modules vs packages vs Library |
# | 14 | Why 0.3 – 0.2 is not equal to 0.1 in Python? |
# | 15 | Python Docstrings |

# %% [markdown]
# ### **`1. What is Python? What are the benefits of using Python?`**
#
# Python is a high-level, interpreted, general-purpose programming language. Being a general-purpose language, it can be used to build almost any type of application with the right tools/libraries. Additionally, python supports objects, modules, threads, exception-handling, and automatic memory management which help in modelling real-world problems and building applications to solve these problems.
#
# **Benefits of using Python:**
# - Python is a general-purpose programming language that has a simple, easy-to-learn syntax that emphasizes readability and therefore reduces the cost of program maintenance. Moreover, the language is capable of scripting, is completely open-source, and supports third-party packages encouraging modularity and code reuse.
# - Its high-level data structures, combined with dynamic typing and dynamic binding, attract a huge community of developers for Rapid Application Development and deployment.

# %% [markdown]
# ### **`2. What is a dynamically typed language?`**
#
# Before we understand a dynamically typed language, we should learn about what typing is. **Typing** refers to type-checking in programming languages. In a **strongly-typed** language, such as Python, **"1" + 2** will result in a type error since these languages don't allow for "type-coercion" (implicit conversion of data types). On the other hand, a **weakly-typed** language, such as Javascript, will simply output **"12"** as result.
#
# Type-checking can be done at two stages:
# - **Static -** Data Types are checked before execution.
# - **Dynamic -** Data Types are checked during execution.
# Python is an interpreted language, executes each statement line by line and thus type-checking is done on the fly, during execution. Hence, Python is a Dynamically Typed Language.
#
# Read more - https://www.techtarget.com/whatis/definition/strongly-typed#:~:text=In%20computer%20programming%2C%20a%20programming,types%20of%20objects%20and%20variables.

# %% [markdown]
# # Programming Language Typing: Strongly Typed vs Weakly Typed
#
#
# # ✅ 1. Strongly Typed Languages
#
# A **strongly typed language** enforces strict rules about how values of different data types are used.
#
# ### ✔ Characteristics
# - Variables have **specific data types**.
# - Incompatible types **cannot be mixed** without explicit conversion.
# - Type errors are caught **early** (compile time or runtime).
# - Helps prevent bugs caused by unexpected type coercion.
#
# ### ✔ Common Strongly Typed Languages
# - Python
# - Java
# - C#
# - Swift
# - Ruby
#
# ### ✔ Example
# ```python
# eg: python
# x = "5"
# y = 10
# print(x + y)   # ❌ Error: can't add string and integer
# ```
#
# # ✅ 2. Weakly Typed Languages
#
# A **weakly typed language** is more flexible about mixing different data types.
# ### ✔ Characteristics
# - Automatic type conversions (implicit coercion).
# - Fewer type restrictions.
# - Errors may occur later or be harder to detect.
#
# ### ✔ Common Weakly Typed Languages
# - JavaScript
# - PHP
# - Perl
# - Bash
#
# ### ✔ Example
# ```
# eg: Javascript
# console.log("5" + 10);   // "510" (string concatenation)
# console.log("5" - 1);    // 4 (coerces "5" to a number)
# ```

# %% [markdown]
# # Programming Language Typing: Static Typed vs Dynamic Typed
#
# **Static Typing** and **Dynamic Typing**.
#
# ---
#
# # ✅ 1. Static Typed Languages
#
# A **statically typed language** checks data types *at compile time* — before the program runs.
#
# ### ✔ Characteristics
# - Variables have a **fixed type** declared or inferred at compile time.
# - Type errors are caught **early**, before execution.
# - Better for performance and large-scale systems.
# - IDEs can provide strong autocomplete and error detection.
#
# ### ✔ Common Statically Typed Languages
# - Java
# - C / C++
# - C#
# - Go
# - Rust
# - Kotlin
# - Swift (with type inference)
#
# ### ✔ Example
# ```java
# int x = 10;
# x = "hello";   // ❌ Compile-time error
# ```
#
# # ✅ 2. Dynamically Typed Languages
#
# Dynamically typed languages determine the type of a variable **at runtime**, not at compile time.
# This provides flexibility and ease of development but may introduce runtime errors if types are misused.
#
# ---
#
# ## 🧩 What Does "Dynamic Typing" Mean?
#
# In dynamically typed languages:
#
# - Variables **don’t have fixed types**.
# - Types belong to **values**, not variables.
# - A variable can hold **different types at different times**.
# - Type checking happens **while the program is running**.
#
# ---
#
# # ✅ Key Characteristics of Dynamic Typing
#
# ### ✔ Runtime Type Checking
# Types are validated when the code is executed, not before.
#
# ### ✔ High Flexibility
# You can reassign different types to the same variable.
#
# ### ✔ Faster to Write
# No need for type annotations or declarations.
#
# ### ✔ Potential for Runtime Errors
# Type-related bugs appear **only when that specific line executes**.
#
# ### ✔ Great for Rapid Development
# Preferred in scripting, prototyping, and high-level programming.
#
# ---
#
# # 🌍 Common Dynamically Typed Languages
#
# - **Python**
# - **JavaScript**
# - **Ruby**
# - **PHP**
# - **Perl**
# - **Lua**
#
# ---
#
# # 💡 Example: Python (Dynamic Typing)
#
# ```python
# x = 10        # x is an integer
# x = "Hello"   # now x is a string
# print(x)      # Output: Hello

# %% [markdown]
# ### **`3. What is an Interpreted language?`**
#
# An Interpreted language executes its statements line by line. Languages such as Python, Javascript, R, PHP, and Ruby are prime examples of Interpreted languages. Programs written in an interpreted language runs directly from the source code, with no intermediary compilation step.

# %% [markdown]
# ### **`4. What is PEP 8 and why is it important?`**
#
# PEP stands for **Python Enhancement Proposal**. A PEP is an official design document providing information to the Python community, or describing a new feature for Python or its processes. **PEP 8** is especially important since it documents the style guidelines for Python Code. Apparently contributing to the Python open-source community requires you to follow these style guidelines sincerely and strictly.
#
# Read more - https://realpython.com/python-pep8/#:~:text=PEP%208%2C%20sometimes%20spelled%20PEP8,and%20consistency%20of%20Python%20code.

# %% [markdown]
# ### **`5. What are the common built-in data types in Python?`**
#
# There are several built-in data types in Python. Although, Python doesn't require data types to be defined explicitly during variable declarations type errors are likely to occur if the knowledge of data types and their compatibility with each other are neglected. Python provides `type()` and `isinstance()` functions to check the type of these variables. These data types can be grouped into the following categories-
#
# 1. **None Type:** **None** keywork represents the null values in Python. Boolean equality operation can be performed using these NoneType objects.
#
# 2. **Numeric Type:** There are three distinct numeric types - `integers`, `floating-point numbers` and `complex numbers`. Additionally, `booleans` are a sub-type of integers.
#
# 3. **Sequence Types:** According to Python Docs, there are three basic Sequence Types - `lists`, `tuples`, and `range` objects. Sequence types have the `in` and `not in` operators defined for their traversing their elements. These operators share the same priority as the comparison operations.
#
# 4. **Mapping Types:** A mapping object can map hashable values to random objects in Python. Mappings objects are mutable and there is currently only one standard mapping type, the `dictionary`.
#
# 5. **Set Types:** Currently, Python has two built-in set types - `set` and `frozenset`. `set` type is mutable and supports methods like *add()* and *remove()*. `frozenset` type is immutable and can't be modified after creation.
#
# 6. **Callable Types:** Callable types are the types to which function call can be applied. They can be **user-defined functions, instance methods, generator functions**, and some other **built-in functions, methods** and **classes**.
# Refer to the documentation at [docs.python.org](https://docs.python.org/3/reference/datamodel.html) for a detailed view of the callable types.

# %% [markdown]
# ###`Q.6. Operator Precedence.`
# https://www.programiz.com/python-programming/precedence-associativity

# %% [markdown]
# ###`Q.7. Explain the ternary operator in Python.`

# %% [markdown]
# Unlike C++, we don’t have ?: in Python, but we have this:
#
#
# > [on true] if [expression] else [on false]
#
#
#
# If the expression is True, the statement under [on true] is executed. Else, that under [on false] is executed.
#
# Below is how you would use it:
#
#
# ```
# a,b=2,3
# min=a if a<b else b
# print(min)
# ```
#
# Above will print 2.

# %%
# Run this cell to see result.
a,b=14,12
print("Hi") if a<b else print("Bye")
# Out:
# Bye

# %% [markdown]
# ### `Q 8. What Does the ‘is’ Operator Do?`
#
# Identity operators<br>
# In Python, is and is not are used to check if two values are located on the same part of the memory. Two variables that are equal does not imply that they are identical.

# %%
a = 1
id(a)
# Out:
# 11126688

# %%
a = 2
id(a)
# Out:
# 11126720

# %%
a = 1
b = 1

a is b
# Out:
# True

# %%
id(a)
# Out:
# 11126688

# %%
id(b)
# Out:
# 11126688

# %%
a = 257
b = 257

a is b
# Out:
# False

# %%
id(a)
# Out:
# 140582907232784

# %%
a == b
# Out:
# True

# %%
id(b)
# Out:
# 140582907232464

# %%
# -5 to 256

a = -14
b = -14

a is b
# Out:
# False

# %% [markdown]
# ### `Q 9: Disadvantages of Python.`
#
# https://www.geeksforgeeks.org/disadvantages-of-python

# %% [markdown]
# ## 🚫 Key Disadvantages of Python
#
# ### 1. Python is Slow at Runtime
# - Python is an **interpreted language**, making it slower than compiled languages like C, C++, or Java.
# - Code execution happens **line-by-line**, causing performance delays or making it slower.
# - Despite this, Python is still fast enough for many web and scripting applications.
#
# ---
#
# ### 2. Weak for Mobile Application Development
# - Python is rarely used for **mobile development**.
# - Limited frameworks and support for mobile apps.
# - Very few mobile apps (e.g., *Carbonnelle*) are built using Python.
#
# ---
#
# ### 3. Difficulty in Using Other Languages
# - Python’s simplicity and powerful libraries can make developers **too dependent** on it.
# - Programmers may find it hard to switch to more complex languages like Java or C++.
#
# ---
#
# ### 4. High Memory Consumption
# - Python uses **more memory** due to flexible data types and high-level data structures.
# - Not suitable for **memory-intensive tasks**.
#
# ---
#
# ### 5. Not Widely Used in Enterprise Development
# - Considered **less secure** for large-scale enterprise applications.
# - Python's database access layer is **underdeveloped** compared to JDBC/ODBC.
# - Not ideal for large enterprises requiring **reliable integration with legacy systems**.
#
# ---
#
# ### 6. Runtime Errors
# - Due to **dynamic typing**, many errors appear only at runtime.
# - Requires extensive(more) testing to catch type-related issues.
# - Python’s design can lead to unexpected runtime behaviors.
#
# ---
#
# ### 7. Simplicity as a Disadvantage
# - Python’s extremely simple syntax may cause developers to become **overly reliant** on it.
# - Transitioning to more complex languages (e.g., Java, C#) can be difficult.
# - This simplicity may encourage a **less disciplined coding style**.

# %% [markdown]
# ### `Q10 How strings are stored in Python?`
# - https://stackoverflow.com/questions/19224059/how-strings-are-stored-in-python-memory-model
# - https://www.quora.com/How-are-strings-stored-internally-in-Python-3
# - https://betterprogramming.pub/an-interviewers-favorite-question-how-are-python-strings-stored-in-internal-memory-ac0eaef9d9c2

# %% [markdown]
# # How Strings Are Stored in Python
# **Interview Guide**
# ---
# ```
# -Python stores strings as immutable Unicode objects using a flexible internal representation (PEP 393).
# -Depending on the characters, Python uses 1, 2, or 4 bytes per character.
# -Strings are stored in contiguous memory, and Python also interns some strings for optimization.
# ```
#
# ---
#
# ## 🔹 1. Strings Are Immutable
# - Python strings **cannot be modified** after creation.
# - Any change creates a **new string object**.
# - Immutability allows strings to be **hashable** and safe to use as dictionary keys.
#
# ---
#
# ## 🔹 2. Strings Are Stored as Unicode
# - Python 3 stores all strings as **Unicode code points**.
# - This supports characters from any language (English, Hindi, Chinese, Emojis, etc.).
# - Every character in a Python string is a Unicode code point.
# ```
# s = "A"
# ord(s)  # 65
# ```
# ---
#
# ## 🔹 3. PEP 393: Flexible String Representation
# Python uses a memory-efficient internal representation depending on the highest character value in the string.
#
# | Character Range      | Storage Format | Bytes per Character |
# |----------------------|----------------|----------------------|
# | Latin-1 (0–255)      | 1-byte         | 1 byte               |
# | Basic Multilingual   | 2-byte         | 2 bytes              |
# | Full Unicode         | 4-byte         | 4 bytes              |
#
# This means Python automatically chooses the smallest storage size needed
# ```
# s1 = "hello"      # Stored in 1 byte per character
# s2 = "हिंदी"      # Stored in 2 or 4 bytes per character
# ```
# ---
#
# Example:
# ```python
# a = "hello"
# b = "hello"
# a is b    # True → interned

# %%
char = 'a'
ord(char)
# Out:
# 97

# %% [markdown]
# ### `Q10 What is Zen of Python?`
#
# The Zen of Python is a collection of 19 "guiding principles" for writing computer programs that influence the design of the Python programming language.
# https://en.wikipedia.org/wiki/Zen_of_Python
#
# * Beautiful is better than ugly.
# * Explicit is better than implicit.
# * Simple is better than complex.
# * Complex is better than complicated.
# * Flat is better than nested.
# * Sparse is better than dense.
# * Readability counts.
# * Special cases aren't special enough to break the rules.
# * Although practicality beats purity.
# * Errors should never pass silently.
# * Unless explicitly silenced.
# * In the face of ambiguity, refuse the temptation to guess.
# * There should be one-- and preferably only one --obvious way to do it.
# * Although that way may not be obvious at first unless you're Dutch.
# * Now is better than never.
# * Although never is often better than *right* now.
# * If the implementation is hard to explain, it's a bad idea.
# * If the implementation is easy to explain, it may be a good idea.
# * Namespaces are one honking great idea -- let's do more of those!
#
# Explained in detail here - https://inventwithpython.com/blog/2018/08/17/the-zen-of-python-explained/

# %% [markdown]
# ### `Q11 Identity operator (is) vs ==?`
#
# ->> Here’s the main difference between python “==” vs “is:”
#
# Identity operators: The “is” and “is not” keywords are called identity operators that compare objects based on their identity.
# Equality operator: The “==” and “!=” are called equality operators that compare the objects based on their values.

# %%
# Case 4:
# Here variable s is assigned a list,
# and q assigned a list values same as s but on slicing of list a new list is generated
s=[1,2,3]
p=s
# cloning
q=s[:]
print("id of p", id(p))
print("Id of s", id(s))
print("id of q", id(q))
print("Comapare- s == q", s==q)
print("Identity- s is q", s is q)
print("Identity- s is p", s is p)
print("Comapare- s == p", s==p)
# Out:
# id of p 140582906466864
# Id of s 140582906466864
# id of q 140582906466944
# Comapare- s == q True
# Identity- s is q False
# Identity- s is p True
# Comapare- s == p True

# %%
a = [1,2,3]
b = a[:]

a.append(4)
print(a)
print(b)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3]

# %% [markdown]
# ### `Q12 What does _ variables represent in Python?`
#
# [GssksForGeeks Article](https://www.geeksforgeeks.org/underscore-_-python)
#
# Underscore _ is considered as "I don't Care" or "Throwaway" variable in Python
#
#
# * The underscore _ is used for ignoring the specific values. If you don’t need the specific values or the values are not used, just assign the values to underscore.
#
# ** Ignore a value when unpacking
#
# ** Ignore the index

# %%
# Ignore a value when unpacking
x, _, y = (1, 2, 3)

print("x-",x)
print("y-", y)
# Out:
# x- 1
# y- 3
# _ 2

# %%
#Ignore the index

# Say we want to print hello 5 times, we don't need index value

for _ in range(5):
    print('hello')
# Out:
# hello
# hello
# hello
# hello
# hello

# %% [markdown]
# ### `Q13 Modules vs packages vs Library`

# %% [markdown]
# Python uses some terms that you may not be familiar with if you’re coming from a different language. Among these are modules, packages, and libraries.
#
# * A **module** is a Python file that’s intended to be imported into scripts or other modules. It often defines members like classes, functions, and variables intended to be used in other files that import it.
#
# * A **package** is a collection of related modules that work together to provide certain functionality. These modules are contained within a folder and can be imported just like any other modules. This folder will often contain a special `__init__` file that tells Python it’s a package, potentially containing more modules nested within subfolders
#
# * A **library** is an umbrella term that loosely means “a bundle of code.” These can have tens or even hundreds of individual modules that can provide a wide range of functionality. Matplotlib is a plotting library. The Python Standard Library contains hundreds of modules for performing common tasks, like sending emails or reading JSON data. What’s special about the Standard Library is that it comes bundled with your installation of Python, so you can use its modules without having to download them from anywhere.
#
# These are not strict definitions. Many people feel these terms are somewhat open to interpretation. Script and module are terms that you may hear used interchangeably.
#
# https://stackoverflow.com/questions/19198166/whats-the-difference-between-a-module-and-a-library-in-python
#
# https://www.geeksforgeeks.org/what-is-the-difference-between-pythons-module-package-and-library/

# %% [markdown]
# # Difference Between Module, Package, and Library in Python
#
#
# ## 1. Module
#
# - A **module** is a **single Python file** (.py) containing code like functions, classes, or variables.
# - Purpose: **Organize and reuse code**.
# - You can import a module using the `import` statement.
#
# **Example:**
# ```python
# # file: math_utils.py
# def add(a, b):
#     return a + b
# ```
#
# ### 2. Package
# - A **package** is a **collection of related modules** stored in a **directory.**
# - Must contain an `__init__.py` file (can be empty).
# - Purpose: **Group related modules** together.
# ```
# Example Directory Structure
# finance/          # package
# │
# ├── __init__.py
# ├── accounting.py  # module
# └── taxes.py       # module
#
# ```
# ### 3. Library
#
# - A library is a collection of packages and modules providing ready-to-use functionality.
# - Purpose: Solve common problems or provide APIs.
# ```
# Examples:
# NumPy → Numerical computing
# Pandas → Data analysis
# Requests → HTTP requests
# ```
#
# | Feature    | Module                    | Package                      | Library                        |
# | ---------- | ------------------------- | ---------------------------- | ------------------------------ |
# | Definition | Single Python file (.py)  | Collection of modules        | Collection of packages/modules |
# | Structure  | One file                  | Directory with `__init__.py` | Can contain multiple packages  |
# | Example    | `math_utils.py`           | `finance/`                   | `NumPy`, `Pandas`              |
# | Purpose    | Code organization & reuse | Group related modules        | Provide ready-to-use tools     |
# | Import     | `import module_name`      | `import package_name.module` | `import library_name`          |

# %% [markdown]
# ### `Q14 Why 0.3 – 0.2 is not equal to 0.1 in Python?`

# %% [markdown]
# The reason behind it is called “*precision*”, and it’s due to the fact that computers do not compute in Decimal, but in Binary. Computers do not use a base 10 system, they use a base 2 system (also called Binary code).
#
# https://www.geeksforgeeks.org/why-0-3-0-2-is-not-equal-to-0-1-in-python/

# %% [markdown]
# ## Python Floating-Point Precision: Why `0.3 - 0.2 != 0.1`
#
# In Python, `0.3 - 0.2` is **not exactly equal to `0.1`** due to **floating-point precision issues/limitations**. Decimal fractions like 0.1, 0.2, or 0.3 cannot be represented exactly in binary because of repeating binary fractions. so,Python stores the nearest possible double-precision approximation and end up as binary approximation of decimal.
#
# ---
#
# ## 🔹 The Issue
#
# ```python
# >>> 0.3 - 0.2
# 0.09999999999999998
# >>> 0.1
# 0.1
# >>> 0.3 - 0.2 == 0.1
# False
# ```
# ###**1. Floating-Point Representation**
#
# - Python uses IEEE 754 double-precision floating-point numbers internally.
# - Many decimal fractions (like 0.1, 0.2, 0.3) cannot be exactly represented in binary.
# - This causes small approximation errors in arithmetic operations.
# ```
# For example:
#
# 0.1 in binary → 0.00011001100110011... (repeating binary fractions)
#
# 0.2 in binary → 0.0011001100110011... (repeating binary fractions)
#
# 0.3 in binary → 0.0100110011001100... (repeating binary fractions)
#
# These repeating binary fractions lead to tiny errors when performing calculations
# This happens due to binary approximation of decimals.
# ```
#
# ###**2. How to handle this ?**
# **a.Use round() for comparison**
# ```
# round(0.3 - 0.2, 1) == 0.1  # True
# ```
#
# **b.Use math.isclose()**
# ```
# import math
# math.isclose(0.3 - 0.2, 0.1)  # True
# ```
#
# **c.Use the decimal module for exact decimal arithmetic**
# ```
# from decimal import Decimal
# Decimal('0.3') - Decimal('0.2') == Decimal('0.1')  # True
# ```
# ###**Key Notes**
# - Floating-point numbers cannot precisely represent all decimal fractions.
# - Small rounding errors occur, especially after arithmetic operations.
# - Always use rounding or Decimal for precise decimal comparison.

# %% [markdown]
# ### `Q 15 - Python Docstrings`
#
# https://www.geeksforgeeks.org/python-docstrings

# %%
print('hello')
# Out:
# hello

# %%
type(3)
# Out:
# int

# %%
print(input.__doc__)
# Out:
# Forward raw_input to frontends
#
#         Raises
#         ------
#         StdinNotImplentedError if active frontend doesn't support stdin.

# %%
print(type.__doc__)
# Out:
# type(object_or_name, bases, dict)
# type(object) -> the object's type
# type(name, bases, dict) -> a new type

# %%
s = 'have'
print(id(s))
s = s.capitalize()
print(id(s))
# Out:
# 140582962705648
# 140582906473392

# %%
a,b = print('hello'),print('world')
print(a,b)
# Out:
# hello
# world
# None None

# %%
for i in range(1, 5): # i -> 1,2,3,4,5
    i = 3
    print(i, end=' ')
# first Iteration ===> i=1 -> i=3 -> print(i,end=' ')
# second Iteration ===> i=2 -> i=3 -> print(i,end=' ')
# Third Iteration ===> i=3 -> i=3 -> print(i,end=' ')
# Forth Iteration ===> i=4 -> i=3 -> print(i,end=' ')
# Out:
# 3 3 3 3
