# %% [markdown]
# <a href="https://colab.research.google.com/github/Sujan078BCT/Python-Programming/blob/main/Solution/session_7_task_solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##`Q-1:` Rectangle Class
# 1. Write a Rectangle class in Python language, allowing you to build a rectangle with length and width attributes.
#
# 2. Create a Perimeter() method to calculate the perimeter of the rectangle and a Area() method to calculate the area of ​​the rectangle.
#
# 3. Create a method display() that display the length, width, perimeter and area of an object created using an instantiation on rectangle class.

# %% [markdown]
# Eg.
# After making above classes and methods, on executing below code:-
# ```
# my_rectangle = Rectangle(3 , 4)
# my_rectangle.display()
# ```
#
# `Output:`
# ```
# The length of rectangle is:  3
# The width of rectangle is:  4
# The perimeter of rectangle is:  14
# The area of rectangle is:  12
# ```

# %%
# Creating Rectangle Class
class Rectangle:
  # Initialize attributes
  def __init__(self,length=1,width=1):
    self.__length = length
    self.__width = width
  # Perimeter Method
  def __perimeter(self): # Used by internal method only but not outside class
    return 2*(self.__length + self.__width)
  # Area method
  def __area(self):   # used by internal method only but not outside class
    return self.__length * self.__width
  # Display method
  def display(self):
    print("The length of rectangle is : {}".format(self.__length))
    print("The width of rectangle is : {}".format(self.__width))
    print("The perimeter of rectangle is : {}".format(self.__perimeter()))
    print("The area of rectangle is : {}".format(self.__area()))

# Creating instance of Rectangle class
my_rectangle = Rectangle(3,4)
my_rectangle.display()
# Out:
# The length of rectangle is : 3
# The width of rectangle is : 4
# The perimeter of rectangle is : 14
# The area of rectangle is : 12

# %% [markdown]
# ##`Q-2: Bank Class`
#
# 1. Create a Python class called `BankAccount` which represents a bank account, having as attributes: `accountNumber` (numeric type), `name` (name of the account owner as string type), `balance`.
# 2. Create a constructor with parameters: `accountNumber, name, balance`.
# 3. Create a `Deposit()` method which manages the deposit actions.
# 4. Create a `Withdrawal()` method  which manages withdrawals actions.
# 5. Create an `bankFees()` method to apply the bank fees with a percentage of 5% of the balance account at the time of withdrawal.
# 6. Create a `display()` method to display account details.
# Give the complete code for the  BankAccount class.

# %% [markdown]
# Eg.
# After making above classes and methods, on executing below code:-
# ```
# newAccount = BankAccount(2178514584, "Mandy" , 2800)
#
# newAccount.Withdrawal(700)
#
# newAccount.Deposit(1000)
#
# newAccount.display()
# ```
#
# `Output:`
# ```
# Account Number :  2178514584
# Account Name :  Mandy
# Account Balance :  2095.0 ₹
# ```

# %%
# write your code here

# Creating BankAccount class
class BankAccount:
  # Initialize attribute
  def __init__(self,accountNumber,name,balance):
    self.__accountNumber = accountNumber
    self.__name = name
    self.__balance = balance
  def Deposit(self,amount):
    self.__balance += amount
  def Withdrawal(self,amount):
    if self.__balance >= amount:
      self.__balance -= amount
      self.__bankFees()
    else:
      print("Not Sufficient Balance.")
  def __bankFees(self): # It is made private because only internal method will use it but not outside class
    self.__balance *= 0.95
  def display(self):
    print("Account Number : {}".format(self.__accountNumber))
    print("Account Name : {}".format(self.__name))
    print("Account Balance : {} ₹".format(self.__balance))

newAccount = BankAccount(2178514584, "Mandy" , 2800)
newAccount.Withdrawal(700)
newAccount.Deposit(100)
newAccount.display()
# Out:
# Account Number : 2178514584
# Account Name : Mandy
# Account Balance : 2095.0 ₹

# %% [markdown]
# ##`Q-3:Computation class`
#
# 1. Create a `Computation` class with a default constructor (without parameters) allowing to perform various calculations on integers numbers.
# 2. Create a method called `Factorial()` which allows to calculate the factorial of an integer n. Integer n as parameter for this method
#
# 3. Create a method called `naturalSum()` allowing to calculate the sum of the first n integers 1 + 2 + 3 + .. + n. Integer n as parameter for this method.
#
# 4. Create a method called `testPrime()` in  the Calculation class to test the primality of a given integer n, n is Prime or Not? Integer n as parameter for this method.
#
# 5. Create  a method called `testPrims()` allowing to test if two numbers are prime between them. Two integers are prime to one another if they have only `1` as their common divisor. Eg. 4 and 9 are prime to each other.
#
# 5. Create a `tableMult()` method which creates and displays the multiplication table of a given integer. Then create an `allTablesMult()` method to display all the integer multiplication tables 1, 2, 3, ..., 9.
#
# 6. Create a static `listDiv()` method that gets all the divisors of a given integer on new list called  Ldiv. Create another `listDivPrim()` method that gets all the prime divisors of a given integer.

# %%
# write your code here
class Computation:
  # Initialize attribute
  def __init__(self):
    pass
  # Factorial method
  def Factorial(self,n):
    fact = 1
    for i in range(1,n+1):
      fact *= i
    return fact
  # Calculate sum to n
  def naturalSum(self,n):
    sum = 0
    for i in range(1,n+1):
      sum += i
    return sum
  # Check if n is prime or not
  def testPrime(self,n):
    if n == 1:
      return False
    is_prime = True
    for i in range(2,n):
      if n % i == 0 :
        is_prime = False
        break
    return is_prime
  # Check if x and y are prime to each other
  def testPrims(self,x,y):
    smallest = x if x<y else y
    is_prime = True
    for i in range(2,smallest+1):
      if x % i == 0 and y % i ==0 :
        is_prime = False
        break
    return is_prime
  # Print multiplication table of n
  def tableMult(self,n):
    print("Multiplication Table of {} : ".format(n))
    for i in range(1,11):
      print("{} * {} = {}".format(n,i,n*i))
  # Print multiplication table from 1 to 9
  def allTablesMult(self):
    for i in range(1,10):
      self.tableMult(i)

  @staticmethod
  def listDiv(num):
    L = []
    for i in range(1,num+1):
      if num % i == 0:
        L.append(i)
    return L

  def listDivPrime(self,num):
    L = []
    for i in range(1,num+1):
      if self.testPrime(i) and num % i == 0:
        L.append(i)
    return L

c1 = Computation()
c1.testPrims(13,7)
print("List of divisors of 18 : ",Computation.listDiv(18))
print("List of prime divisors of 18:",c1.listDivPrime(18))
c1.allTablesMult()
# Out:
# List of divisors of 18 :  [1, 2, 3, 6, 9, 18]
# List of prime divisors of 18: [2, 3]
# Multiplication Table of 1 :
# 1 * 1 = 1
# 1 * 2 = 2
# 1 * 3 = 3
# 1 * 4 = 4
# 1 * 5 = 5
# 1 * 6 = 6
# 1 * 7 = 7
# 1 * 8 = 8
# 1 * 9 = 9
# 1 * 10 = 10
# Multiplication Table of 2 :
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18
# 2 * 10 = 20
# Multiplication Table of 3 :
# 3 * 1 = 3
# 3 * 2 = 6
# 3 * 3 = 9
# 3 * 4 = 12
# 3 * 5 = 15
# 3 * 6 = 18
# 3 * 7 = 21
# 3 * 8 = 24
# 3 * 9 = 27
# 3 * 10 = 30
# Multiplication Table of 4 :
# 4 * 1 = 4
# 4 * 2 = 8
# 4 * 3 = 12
# 4 * 4 = 16
# 4 * 5 = 20
# 4 * 6 = 24
# 4 * 7 = 28
# 4 * 8 = 32
# 4 * 9 = 36
# 4 * 10 = 40
# Multiplication Table of 5 :
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
# 5 * 10 = 50
# Multiplication Table of 6 :
# 6 * 1 = 6
# 6 * 2 = 12
# 6 * 3 = 18
# 6 * 4 = 24
# 6 * 5 = 30
# 6 * 6 = 36
# 6 * 7 = 42
# ...

# %% [markdown]
# ##`Q-4`: Build flashcard using class in Python.
#
# Build a flashcard using class in python. A flashcard is a card having information on both sides, which can be used as an aid in memoization. Flashcards usually have a question on one side and an answer on the other.
#
# **Example 1:**
#
# Approach:
#
# - Create a class named FlashCard.
# - Initialize dictionary fruits using __init__() method. Here you have to define fruit name as key and it's color as value. E.g., {"Banana": "yellow", "Strawberries": "pink"}
# - Now randomly choose a pair from fruits by using _random_ module and store the key in variable _fruit_ and _value_ in variable color.
# - Now prompt the user to answer the color of the randomly chosen fruit.
# - If correct print correct else print wrong.
#
# Output:
# ```bash
# welcome to fruit quiz
# What is the color of Strawberries
# pink
# Correct answer
# Enter 0, if you want to play again: 0
# What is the color of watermelon
# green
# Correct answer
# Enter 0, if you want to play again: 1
# ```

# %%
# select random element from a list
import random
L = [1,2,3,5,9]
random.choices(L)[0]
# Out:
# 1

# %%
import random
d = {
        "Banana":"yellow",
        "Strawberries":"pink",
        "Watermelon":"green",
        "Apple":"red",
        "Mango":"green"
    }
# Select random pair(Key and value) i.e fruit from dictionary
random.choices()
fruit,color = random.choices(list(d.items()))[0]
print(fruit,color)
# Out:
# Banana yellow

# %%
# write your code here
import random

# Creating FlashCard class
class FlashCard:
  # Initialize attributes
  def __init__(self):
    self.__fruits = {
        "Banana":"yellow",
        "Strawberries":"pink",
        "Watermelon":"green",
        "Apple":"red",
        "Mango":"green"
        }
    self.__quiz()

  # Creating quiz method
  def __quiz(self): # this method is internally used by internal method
    fruit,color = random.choices(list(self.__fruits.items()))[0]
    user_input = input("What is the color of {} : ".format(fruit))
    if user_input == color :
      print("Correct answer")
    else:
      print("Incorrect answer")
    try_again = input("Enter 0, if you want to play again : ")
    if try_again == '0':
      self.__quiz()

# creating instance of FlashCard
print("Welcome to the Fruit Quiz : ")
flashcard = FlashCard()
# Out:
# Welcome to the Fruit Quiz :
# What is the color of Watermelon : green
# Correct answer
# Enter 0, if you want to play again : no

# %% [markdown]
# ## `Q-5:` Problem 5 based on OOP Python.
#
# TechWorld, a technology training center, wants to allocate courses for instructors. An instructor is identified by name, technology skills, experience and average feedback. An instructor is allocated a course, if he/she satisfies the below two conditions:
# - eligibility criteria:
#     - if experience is more than 3 years, average feedback should be 4.5 or more
#     - if experience is 3 years or less, average feedback should be 4 or more
# - he/she should posses the technology skill for the course
#
# Identify the class name and attributes to represent instructors. Write a Python program to implement the class chosen with its attributes and methods.
#
# **Note:**
# - Consider all instance variables to be private and methods to be public.
# - An instructor may have multiple technology skills, so consider instance variable, technology_skill to be a list.
# - *check_eligibility()*: Return true if eligibility criteria is satisfied by the instructor. Else, return false
# - *allocate_course(technology)*: Return true if the course which requires the given technology can be allocated to the instructor. Else, return false.
#
# Represent a few objects of the class, initialize instance variables using setter methods, invoke
# appropriate methods and test your program.

# %%
# write your code here
class Instructor:
  def __init__(self,name,technology,experience,feedback):
    self.__name = name
    self.__skills = technology
    self.__experience = experience
    self.__avg_feedback = feedback

  # defining getter method
  def getName(self):
    return self.__name
  def getSkills(self):
    return self.__skills

  def getExperience(self):
    return self.__experience

  def getAverageFeedback(self):
    return self.__avg_feedback

  # defining setter method
  def updateName(self,newName):
    self.__name = newName

  def updateSkills(self,newSkills):
    self.__skills = newSkills

  def updateExperience(self,newExperience):
    self.__experience = newExperience

  def updateAvgFeedback(self,newFeedback):
    self.__avg_feedback = newFeedback

  def __check_eligibility(self):
    if self.__experience > 3 and self.__avg_feedback >= 4.5:
      return True
    elif self.__experience <=3 and self.__avg_feedback >= 4.0:
      return True
    else:
      return False

  def allocate_course(self,technology):
    if self.__check_eligibility():
      for techno in technology:
        if techno not in self.__skills:
          return False
        return True
    else:
      return False


instructor1 = Instructor('Hari',['Data Science','Web Development'],5,4.3)
instructor1.allocate_course(['Data Science'])
# Out:
# False
